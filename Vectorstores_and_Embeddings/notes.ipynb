# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Vector Stores

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Embeddings

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Vector Stores

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
